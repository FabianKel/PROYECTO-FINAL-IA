# %%
import joblib

with open("models/knn_original_3_preprocessed.pkl", "rb") as f:
    model1 = joblib.load(f)

with open("models/svm_actual_3_preprocessed.pkl", "rb") as f:
    model2 = joblib.load(f)

with open("models/knn_actual_3_preprocessed.pkl", "rb") as f:
    model3 = joblib.load(f)

for col_m1, col_m2, col_m3 in zip(model1.feature_names_in_, model2.feature_names_in_, model3.feature_names_in_):
    equal = col_m1 == col_m2 and col_m1 == col_m3
    print(equal)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
